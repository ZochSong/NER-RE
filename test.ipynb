# %%
from .named_entity_recogition import *
from .relation_extract import *
from ner_re import NerReModel

ner_model = BertCrfForNer(num_labels=8)
ner_model = NerWorker(ner_model)

# %%
ner_model.load_training_data('./datasets/training_data.txt')
ner_model.train(20)

# %%
ner_model.predict('胡歌毕业于上海戏剧学院，中国内地男演员、歌手、制片人')

# %%
re_model = BertForRe(13)
re_model = ReWorker(re_model)

# %%
training_data_path = 'datasets/re_training_data.txt'
re_model.load_training_data(training_data_path)
re_model.train(epochs=9)

# %%
# ner_model.load('ner_model_save')
# re_model.save()

# %%
pipeline = NerReModel(ner_model_path='ner_model_save')

# %%
result = pipeline.extract("胡歌是上海人，毕业于上海戏剧学院", verbose=True)
